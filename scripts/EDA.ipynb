# %%
import pandas as pd

# %%
df = pd.read_csv('medium-english-50mb.csv')

print(df.shape)
print(df.columns)
print(df.head())
print(df.isna().sum())
# Out:
# (7682, 6)
# Index(['title', 'text', 'url', 'authors', 'timestamp', 'tags'], dtype='object')
#                                                title  \
# 0                                Mental Note Vol. 24
# 1                          Your Brain On Coronavirus
# 2                                     Mind Your Nose
# 3                   Surviving a Rod Through the Head
# 4  Mentally, Young Adults Are Suffering Most From...
#
#                                                 text  \
# 0  Photo by Josh Riemer on Unsplash\n\nMerry Chri...
# 1  Your Brain On Coronavirus\n\nA guide to the cu...
# 2  Mind Your Nose\n\nHow smell training can chang...
# 3  You’ve heard of him, haven’t you? Phineas Gage...
# 4  Mentally, Young Adults Are Suffering Most From...
#
#                                                  url            authors  \
# 0  https://medium.com/invisible-illness/mental-no...       ['Ryan Fan']
# 1  https://medium.com/age-of-awareness/how-the-pa...  ['Simon Spichak']
# ...
